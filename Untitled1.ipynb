# %% [markdown]
# # Intro to Python
# - [Input and Output](# Input-and-Output)
# -[Python Variable](#Pyhon-Variable)

# %% [markdown]
# ## Input and Output

# %%
input()
# Out:
#  Hi there
# 'Hi there'

# %%
input("Type your name")
# Out:
# Type your name Joseph Sevier
# 'Joseph Sevier'

# %%
print("Hi there")
# Out:
# Hi there

# %%
print("AAAA","BBBBB","CCCCCC")
# Out:
# AAAA BBBBB CCCCCC
